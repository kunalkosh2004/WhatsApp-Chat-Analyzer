# %%
import pandas as pd
import re

# %%
url1 = '_chat 4.txt'
url2 = 'WhatsApp Chat with Iiit unofficial.txt'

# %%
file = open(url2,'r',encoding='utf-8')

# %%
data=file.read()

# %%
pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
date_pattern = r'\d{1,2}/\d{1,2}/\d{1,2},\s\d{1,2}:\d{1,2}'
pattern1 = r'\[\d{1,2}\/\d{1,2}\/\d{1,2}\,\s\d{1,2}\:\d{1,2}\:\d{1,2}\]\s'
date_pattern1 = r'\[\d{1,2}\/\d{1,2}\/\d{1,2}\,\s\d{1,2}\:\d{1,2}\:\d{1,2}\]'

# %%
messages = re.split(pattern,data)[1:]

# %%
if len(messages)==0:
    messages = re.split(pattern1,data)[1:]

# %%
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Labhanshu Meetha created group "Iiit unofficial"\n',
#  'Labhanshu Meetha added you\n',
#  'Labhanshu Meetha added Protien Iiitb\n',
#  'Labhanshu Meetha added +91 99733 25733\n',
#  'Labhanshu Meetha added +91 91043 20838\n',
#  'Rishit Iiit IT: Bois college ke wifi ka password ka kya scene.\n',
#  'Hooda Iiit: Password wassword pata lagao bole to ek number\n',
#  'Vishal Maurya ECE: https://www.instagram.com/reel/CjpxWxGJPpQ/?igshid=YmMyMTA2M2Y=\n',
#  'Om South Iiit: Breakfast aaya toh batao...\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Dev Iiit B Ece: Breakfast aaya kya\n',
#  'Binod Iiit: Nhi Bhai kuch nahi h\n',
#  'Puru Arora CSE added +91 83034 62952\n',
#  'Labhanshu Meetha added +91 95895 01441\n',
#  '+91 95895 01441: <Media omitted>\n',
#  '+91 95895 01441: https://t.me/iiitbhopalfreshers22\n',
#  'Om South Iiit: Aare koi orientation ka schedule s3nd karo\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Rishit Iiit IT: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vishal Maurya ECE: This message was deleted\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  'Madhav Iiit: 1:15 pe bus nikal jaegi\n',
#  'Madhav Iiit: Khana aa gaya hai\n',
#  'Madhav Iiit: Mess me\n',
#  '+91 77278 13841: Kisi ko pta h kya h ki kl website p kya update hua h\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: contact me\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Yash Scanner: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Rishit Iiit IT: null\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Labhanshu Meetha: <Media omitted>\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  'Labhanshu Meetha: Tu toh out tha na be baatein band kar😂\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 95895 01441: Punya Modi Aakash And iiit Bhopal IT.vcf (file attached)\n',
#  '+91 95895 01441: Please add this number\n',
#  'Labhanshu Meetha added Punya Modi Iiit\n',
#  'Labhanshu Meetha added +91 77372 59757\n',
#  'Hooda Iiit: Bc aana kidhar hai\n',
#  'Punya Modi Iiit: This message was deleted\n',
#  'Aman Iiit ECE: maine pad liya\n',
#  'Hooda Iiit: Hall kidhar hai\n',
#  'Hooda Iiit: Kya\n',
#  'Aman Iiit ECE: rgpv boys hostel mai\n',
#  'Hooda Iiit: Chutiya hai kya\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Hooda Iiit: Toh gandu bata na kidhar ana hai\n',
#  'Hooda Iiit: Manit campus me kidhar hai auditorium\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  'Madhav Iiit: All hostler has to pay $200 for tiffin\n',
#  'Madhav Iiit: To caretaker\n',
#  'Madhav Iiit: Aur Haa currency Indian hai\n',
#  '+91 99733 25733: Bhai US sa kon iya ha\n',
#  'Binod Iiit: <Media omitted>\n',
#  'Rishit Iiit IT: @917665841879\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  'Rishit Iiit IT: SURE\n',
#  'Rishit Iiit IT: null\n',
#  'Rishit Iiit IT: Meet harsh hooda\n',
#  'Hooda Iiit: Meet my daughter rinkiya\n',
#  'Rishit Iiit IT: Rinkiya ke pass aiye\n500 rps per hour\nNO BARGAINING\nfamilly discount available\n',
#  'Punya Modi Iiit: This message was deleted\n',
#  '+91 95895 01441: https://chat.whatsapp.com/CWdNxy2Vj3tGWeNvU6ihsZ\n',
#  'Rishit Iiit IT: Add him pls\n',
#  'Rishit Iiit IT: Sannidhya Awasthi IIT BHOPAL (ECE).vcf (file attached)\n',
#  'Labhanshu Meetha added +91 93051 05669\n',
#  'Labhanshu Meetha added Divyansh Sir IIITB\n',
#  'Labhanshu Meetha removed Divyansh Sir IIITB\n',
#  'Rishit Iiit IT: Bhai intro Dena hai kya\n',
#  'Rishit Iiit IT: Group pe?\n',
#  '+91 95895 01441: Discord par\n',
#  'Labhanshu Meetha added +91 63862 69355\n',
#  'Labhanshu Meetha added +91 79034 07643\n',
#  'Labhanshu Meetha added Arth Iiit\n',
#  'Dev Iiit B Ece: Khana aagya kyaa\n',
#  'Himank Iiit: Khana aa gya ha\n',
#  'Yash Scanner: <Media omitted>\n',
#  'Rahul Iiit: What a dance by lavanshu\n',
#  'Rahul Iiit: 🫡🫡🔥🔥🔥\n',
#  'Labhanshu Meetha: Bhai bhai bhai bhai\n',
#  'Hentai IIIT: #labhanshu\n',
#  'Hentai IIIT: 😁\n',
#  'Rahul Iiit: #labanshu\n',
#  'Hentai IIIT: 🔥\n',
#  'Aman Iiit ECE: #Warden\n',
#  '+91 98175 44050: This message was deleted\n',
#  'Labhanshu Meetha: 😂😂\n',
#  'Kunal: #labhanshu\n',
#  'Aman Iiit ECE: This message was deleted\n',
#  'Himank Iiit: <Media omitted>\n',
#  'Himank Iiit: New rate list\n',
#  'Aman Iiit ECE: This message was deleted\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Puru Arora CSE: <Media omitted>\n',
#  'Puru Arora CSE: <Media omitted>\n',
#  'Puru Arora CSE: <Media omitted>\n',
#  'Labhanshu Meetha added Nihar Neta\n',
#  'Labhanshu Meetha added Naman Iiit Cs\n',
#  'Labhanshu Meetha added Suyash Iiit B Cs\n',
#  'Puru Arora CSE added +91 93586 17312\n',
#  'Vishal Maurya ECE: Break fast aa gaya hai\n',
#  '+91 98175 44050: hi this is Manjeet\n',
#  '+91 98175 44050: pay 10 rupees for cricket ball\n',
#  '+91 98175 44050: whoever want to play\n',
#  '+91 98175 44050: on 9817544050\nonly paytm phonepay accepted\n',
#  '+91 98175 44050: or pay to upi id 9817544050@paytm\n',
#  '+91 98175 44050: also tell me through which you have payed\n',
#  'Nid Timepass: This message was deleted\n',
#  '+91 98175 44050: everyone who want to play cricket get to the ground\n',
#  '+91 87919 07421: Lunch aagya kya?\n',
#  'Yash Scanner: <Media omitted>\n',
#  'Yash Scanner: Nhi aya\n',
#  '+91 95895 01441: Bhai lunch aaye to batana please\n',
#  'Likhit Kumar: Agaya\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  '+91 95895 01441: Ok thanks bhai👍\n',
#  'Hooda Iiit: <Media omitted>\n',
#  'Hooda Iiit: *Coming Back 🚪*\n"If you want to gain real control over your destiny, you must understand *reincarnation* and how it works. It\'s that simple."\nJoin us in the next session of *Bace Hostel🛕*, to understand "Coming Back".\n(Only for Boys)\n\n*🎙️ SPEAKER-* H.G. Srinidhi Prabhu*\n\n*🗓️ DATE- 12th November*\n*🕑 TIME 6:30-8:30PM*\n\n*📍Event Location*\n👉 139 Vaishali Nagar, 4th House from Manit Chakri Gate*\n\n🙋🏻\u200d♂👇✨\n*Let us know if you are coming so that we can manage the dinner feast accordingly*\n',
#  'Hooda Iiit: Koi jana chahta hai toh text me your name\n',
#  'Labhanshu Meetha added +91 86172 51132\n',
#  'Atif Iiit: Hai ky yeh ?\n',
#  'Rishit Iiit IT: 4th year MANIT senior ne bola hai \nProgramme is for interaction between IIIT and manit students\n',
#  'Labhanshu Meetha added Aditya Iiit\n',
#  'Labhanshu Meetha added +91 84012 00825\n',
#  '+91 87919 07421: Dinner aaya\n',
#  'Aman Iiit ECE: nhi\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Hooda Iiit: Aadmi ghuma hai ya plate\n',
#  'Kunal: Dono sath me\n',
#  'Hooda Iiit: Ek number\n',
#  'Hooda Iiit: 👌🏻\n',
#  'Aman Iiit ECE: lost spoon in Hand\n',
#  'Hentai IIIT: #Deepak\n',
#  'Hentai IIIT: Missing person\n',
#  'Hooda Iiit: Bhai tu sachme ek ghuma hua chammach dhundh raha hai toh kal akar mujhse thukjaana mast\n',
#  'Kunal: Aman ki taraf se 1.5L ka prize\n',
#  'Rahul Iiit: <Media omitted>\n',
#  'Aman Iiit ECE: L for 🤨\n',
#  'Kunal: Aman\n',
#  'Hooda Iiit: Isko rope se baaandhke rakhna agli baar wapis na ghumjae\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Hooda Iiit: 😂\n',
#  'Madhav Iiit: <Media omitted>\n',
#  'Madhav Iiit: Vishal maurya se lelena A38\n',
#  'Rahul Iiit: Bhai mera hai\n',
#  'Rahul Iiit: Kahaan  milega vishaal\n',
#  'Rahul Iiit: Room no. Batao\n',
#  'Labhanshu Meetha added +91 95989 91647\n',
#  'Labhanshu Meetha added +91 96961 53195\n',
#  'Vishal Maurya ECE: Madhav ke room me aaja\n',
#  'Vishal Maurya ECE: U have 5minutes\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Puru Arora CSE added Mohan Iiit\n',
#  'Vishal Maurya ECE: A19\n',
#  'Vishal Maurya ECE: Me aaja\n',
#  'Vishal Maurya ECE: Jaldi\n',
#  'Abhinav Iiit: <Media omitted>\n',
#  'Punya Modi Iiit: Lunch a gaya?\n',
#  'Atif Iiit: This message was deleted\n',
#  'Vikas Iiit Cse Cr: Guys come inside messs asap\n',
#  'Labhanshu Meetha added +91 91984 71151\n',
#  'Puru Arora CSE: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: 8382929157\nAchyut Pandey\nAdd him\nThe new guy in hostel\n',
#  'Puru Arora CSE added Aditya Pandey IT\n',
#  'Labhanshu Meetha added +91 63779 49627\n',
#  'Labhanshu Meetha added +91 83829 29157\n',
#  '+91 91984 71151: 6005002862 Add this no.shashank\n',
#  '+91 87919 07421: Aagya lunch\n',
#  'Labhanshu Meetha: Lunch aagya kya?\n',
#  'Dev Iiit B Ece: This message was deleted\n',
#  'Rahul Iiit: Photo kheech ke bhej\n',
#  'Punya Modi Iiit: Ok thx\n',
#  'Abhinav Iiit: <Media omitted>\n',
#  'Bhuvan Cse: Kisne bejha yehh\n',
#  'Bhuvan Cse: ?\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Bhuvan Cse: https://www.livehindustan.com/madhya-pradesh/story-seniors-assaulted-junior-student-at-mits-gwalior-mp-gun-mounted-on-the-head-5-suspended-7342512.html\n',
#  'Bhuvan Cse: 😂\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Puru Arora CSE added govind mishra Iiit\n',
#  'Atif Iiit: Bhai sab paise contribute kar late hai Wi-Fi ke liye so that kal parso ke lag jaye\n',
#  'govind mishra Iiit: Bhai maine Manish sir ko bola h\n',
#  'govind mishra Iiit: Ruk jao thoda\n',
#  'Atif Iiit: Par jab tak comtribute ni karoge tab tak lagaga kaise\n',
#  'govind mishra Iiit: Itna hostel fee diya h in logo ko Dena chahiye na\n',
#  'Atif Iiit: Bhai isme ab kon kay he karega we cant fight with the management and since we all are new ni karna chaiye\n',
#  'govind mishra Iiit: Bhai tum pehle hi dar gye\n',
#  'govind mishra Iiit: Tab to lag gya wifi\n',
#  'Atif Iiit: Official site dheko hostel ka mention hai sab kuch Wi-Fi but ni hai Kay kare\n',
#  'Punya Modi Iiit: Le management\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  'Atif Iiit: 😂😂😂\n',
#  'Atif Iiit: Lagana hai khudse sabko apna apna block ma\n',
#  'govind mishra Iiit: Lad k lenge tum wait kro Mai krta hu in logo se baat 2-3 din wait kr lo\n',
#  'Atif Iiit: Toh chalo contribute karte hai and laga late hai khudse\n',
#  'govind mishra Iiit: Bhai yr tum 2 din to wait kr lo\n',
#  'govind mishra Iiit: Krwate h na unhi logo se\n',
#  'govind mishra Iiit: Nahi hoga khud kr lenge\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  'Atif Iiit: Wahi\n',
#  'govind mishra Iiit: Bhai nahi hoga to\n',
#  'govind mishra Iiit: Abhi 2 din un logo pr pressure banate h pehle\n',
#  '+91 63779 49627: Shi kh rha h pr 2-3 se nhi jyada bnde bolenge tab bt bnegi .\n',
#  'govind mishra Iiit: To sb mil k bolo na yr Manish sir se sham me ki vo jaa k warden se hamare liye baat kre\n',
#  '+91 84012 00825: Mar peet thodi kar rahe hai\n\nFees diya hai to mang rahe hai bhai\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  'Labhanshu Meetha added +91 74407 00243\n',
#  '+91 86172 51132: Dinner aa gaya kya?\n',
#  'Binod Iiit: Bhai khatm bhi hone wala hoga\n',
#  'Binod Iiit: Aadho se jaada ne to kha bhi liya\n',
#  'Naman Iiit Cs: Bhai college ki regular timing kaya hai\n',
#  'Naman Iiit Cs: 15 se\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Om South Iiit: Bhai log cricket khelne aa jao\n',
#  'Om South Iiit: Basketball ground pe\n',
#  'Om South Iiit: Bring water bottles\n',
#  'Vishal Maurya ECE: Omkar Tuptewar.vcf (file attached)\n',
#  'Vishal Maurya ECE: @916261402252\n',
#  'Vishal Maurya ECE: Add kar isko\n',
#  'Labhanshu Meetha: K\n',
#  'Labhanshu Meetha added +91 94216 64615\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  'Punya Modi Iiit: Snacks timing kya hai?\n',
#  '+91 87919 07421: Snacks agya kiya?\n',
#  '+91 87919 07421: Aagya\n',
#  '+91 77278 13841: Kya aaya\n',
#  'ARYAN IIIT ECE: Aj nhi ayega\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 84012 00825: Bhel hai🥲\n',
#  'Aman Iiit ECE: all of you come to mess\n',
#  'Vikas Iiit Cse Cr: Pranav A8 IIITB.vcf (file attached)\n',
#  'Vikas Iiit Cse Cr: Add him\n',
#  'Aman Iiit ECE: seniors are here for a small session\n',
#  'Labhanshu Meetha: 4th year  seniors have come to tell us about a club of iiit bhopal so everyone gather in mess\n',
#  '+91 77278 13841: When\n',
#  'Hooda Iiit: Bhai\n',
#  'Hooda Iiit: Please mera bata dena na ki badminton khelta hu\n',
#  'Labhanshu Meetha: Right now\n',
#  'Hooda Iiit: National\n',
#  'Hooda Iiit: Me and @917304706379\n',
#  'Rishit Iiit IT: Yessir\n',
#  'Puru Arora CSE added Atharv Iiit\n',
#  'Labhanshu Meetha added +91 94516 98019 and +91 98902 35487\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  '+91 96743 50711: Yes\n',
#  'Puru Arora CSE added Aryaman Iiit\n',
#  "Madhav Iiit: Let's goooooo\n",
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Lakshya Iiit: <Media omitted>\n',
#  'Aditya Iiit: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  '+91 88269 17687: <Media omitted>\n',
#  'Mohan Iiit: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Gujju Ganjedi Iiit: <Media omitted>\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Aditya Iiit: <Media omitted>\n',
#  'Lakshya Iiit: <Media omitted>\n',
#  'Lakshya Iiit: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  "+91 96961 53195: Size don't matter...speed matters 😌\n",
#  'Vikas Iiit Cse Cr added Abdulla Iiit Cse and Birendra Bhai\n',
#  '+91 84012 00825: Khana kab milega🥲\n',
#  'Birendra Bhai: This message was deleted\n',
#  'Birendra Bhai: Aja bhai du😂\n',
#  '+91 84012 00825: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Aman Iiit ECE: maine engineering kyun ki🥲🥲🥲\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  'Aman Iiit ECE: https://forms.gle/LULqRiFbyWw2yqAb6\n',
#  'Punya Modi Iiit: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  '+91 84012 00825: This message was deleted\n',
#  '+91 84012 00825: 👀\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  '+91 87919 07421: Khana agya kiya?\n',
#  'Vishal Maurya ECE: Aa Jao sab, khana aa gaya\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'ARYAN IIIT ECE: Haa\n',
#  'Puru Arora CSE added +91 70176 14074\n',
#  'Hooda Iiit: Bhai log aur koi issue araha hai kya hostel me?\n',
#  'Hooda Iiit: Apan log 2nd year seniors se bol sakte agar kuch hai toh\n',
#  '+91 70505 83008: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/I2bDKqJKFPAJGBtMrtqf6A\n',
#  '+91 95895 01441: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  'Puru Arora CSE: <Media omitted>\n',
#  'Puru Arora CSE: Mess time pe sbko sign krne hai ispe\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Puru Arora CSE added +91 83030 24738\n',
#  'Puru Arora CSE added +91 73850 74428\n',
#  'Vikas Iiit Cse Cr added Rohith Lanja\n',
#  'Atif Iiit: Dinner aagaya Kay ?\n',
#  'Rahul Iiit: Paneer ki sabzi bani hai\n',
#  'Rahul Iiit: Agaya\n',
#  'Atif Iiit: Okeyy\n',
#  'Arth Iiit: Abhi kaha milega ye\n',
#  '+91 70078 75395: This message was deleted\n',
#  '+91 94154 46373: Jyada sooj gyi kya bhai?\n',
#  'Abhishek Iit B Ece: 😂\n',
#  '+91 70078 75395: This message was deleted\n',
#  '+91 94154 46373: Aaye haaye pair tk dard chala gya😢\n',
#  "Mohan Iiit: Gentle information from seniors for our batch:-\n1. Wish Every senior with good morning/afternoon sir / mam\n2. Don't sit in corridors\n",
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 96961 53195: <Media omitted>\n',
#  'Vishal Maurya ECE: Kya hai ye\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 96961 53195: Abe apni class me ek activity hui thi\n',
#  'Vishal Maurya ECE: Ohk\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 96961 53195: <Media omitted>\n',
#  'Hentai IIIT: <Media omitted>\n',
#  'Hooda Iiit: NTB Gate par saare football waale milne chahiye proper line se 2.45 pm tak\n',
#  'Hooda Iiit: Lower pehenke hi ajana change karne ki jagah nahi milegi\n',
#  'Hooda Iiit: Shorts lower ke neeche pehenke hi ana\n',
#  '+91 84012 00825: 👀\n',
#  'Hooda Iiit: Forward kara hai bhai\n',
#  'Yash Scanner: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/DofIqYtqgnwLPpRlSwR2SV\n',
#  'Labhanshu Meetha added +91 70234 78390\n',
#  'Rahul Iiit: Happy Birthday arham bro🥃\n',
#  'Hentai IIIT: Happy birthday bro\n',
#  '+91 70176 14074: Happy birthday arham\n',
#  '+91 95895 01441: <Media omitted>\n',
#  'Abhishek Iit B Ece: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/BCVqrP5JkXkG0wVijXSKAc\n',
#  'Abhishek Iit B Ece: Those who are interested in volleyball plss join this link\n',
#  'Abhishek Iit B Ece: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  'Abhishek Iit B Ece: Plss join this link\n',
#  'Puru Arora CSE: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  'Vishal Maurya ECE: Ye kaunsi hai??\n',
#  'Puru Arora CSE: Scholarship ka\n',
#  'Dev Iiit B Ece: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  'Dev Iiit B Ece: Join Asap\n',
#  'Aman Iiit ECE: scholarship grp\n',
#  '+91 89601 70220: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  '+91 89601 70220: Scholarship ke gp. Ka link hai\n',
#  'Puru Arora CSE added +91 91258 29620\n',
#  'Puru Arora CSE added +91 70675 28948\n',
#  'Yash Scanner: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/JvS43ILp1Qb6HiJG9GilbS\n',
#  'Yash Scanner: Both boys and girls in this grp\n',
#  'Yash Scanner: 👆👆👆\n',
#  'Punya Modi Iiit: https://chat.whatsapp.com/Bb3QUzpirNr4ydMo6Aq01C\n',
#  'Punya Modi Iiit: Scholarship group\n',
#  'Atharv Iiit: https://chat.whatsapp.com/JvS43ILp1Qb6HiJG9GilbS\n\n\nGroup for all 1st year\n',
#  'Dev Iiit B Ece: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/I3yLgxZiDb7623ansMUyLZ\n',
#  'Atharv Iiit: Vaibhav Sir Scholarship UP.vcf (file attached)\n',
#  'Binod Iiit: Bhai ab ye kisliye h yar\n',
#  '+91 70078 75395: This message was deleted\n',
#  'Atharv Iiit: Isme ladkia ladke sab added h\n',
#  'Yash Scanner: Boys nd girls unofficial grp.. Made by girls\n',
#  'Binod Iiit: Sabko admin ban na h\n',
#  'Dev Iiit B Ece: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/I3yLgxZiDb7623ansMUyLZ\n',
#  'Dev Iiit B Ece: All branch common group\n',
#  'Dev Iiit B Ece: Made by senior\n',
#  'Aman Iiit ECE: <Media omitted>\n',
#  'Binod Iiit: https://chat.whatsapp.com/JvS43ILp1Qb6HiJG9GilbS\n',
#  'Binod Iiit: Bhai is gp ko join karlo jis ne nahi kiya h\n',
#  'Hooda Iiit: Urgent suno sabh\n',
#  'Hooda Iiit: Yashwant raj ece ka hai koi?\n',
#  'Hooda Iiit: Koi ek ece ka banda apna naam batao\n',
#  'Hooda Iiit: Urgently\n',
#  'Hooda Iiit: Bolo na jaldi\n',
#  'Aryaman Iiit: Voh gayab ho gya hai yeh kisne bola?\n',
#  'Hooda Iiit: Tu ece me hai?\n',
#  'Aryaman Iiit: I am from cse\n',
#  '+91 63779 49627: Kya hogya Bhai\n',
#  'Hooda Iiit: Ece wala hai koi\n',
#  'Rishit Iiit IT: Yess\n',
#  'Hooda Iiit: Ece me kon hai batao jaldi!\n',
#  '+91 63779 49627: M hu bhai , bol ?\n',
#  '+91 83030 24738: Mai bhi hu\n',
#  '+91 83030 24738: ECE\n',
#  'Hooda Iiit: Mila kya woh\n',
#  'Hooda Iiit: Yashwant\n',
#  'Gaurav Baby Pink: Yashwant koi ho to msg kro yr\n',
#  'Gaurav Baby Pink: Yashwardhan bhi chlega\n',
#  'Binod Iiit: Y name s hi chahiye kya?\n',
#  'Hooda Iiit: Haaa abhe kaha gaya woh\n',
#  'Binod Iiit: Yash h na ece me\n',
#  'Binod Iiit: Ye rha\n',
#  '+91 63779 49627: Bhai dusre ki baat kr rha h vo\n',
#  'Hooda Iiit: Abhe football khelne aya tha kon kon aaj\n',
#  'Hooda Iiit: Ece branch se\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Binod Iiit: This message was deleted\n',
#  'Binod Iiit: This message was deleted\n',
#  'Binod Iiit: This message was deleted\n',
#  'Binod Iiit: This message was deleted\n',
#  'Hooda Iiit: Joh joh ece se football me aaye the ekbar naam batao sare jano ke\n',
#  'Hooda Iiit: Sirf ece walo ke naam batana\n',
#  'Hooda Iiit: Sabh senior log ke call aye abhi jaldi se jaldi pata karke batao\n',
#  '+91 94516 98019: Pranav yadav, ece\n',
#  'Hooda Iiit: Aur kon kon tha\n',
#  'Hooda Iiit: White tshirt aur shorts wala tha na ek\n',
#  'Hooda Iiit: Woh kon tha\n',
#  '+91 84012 00825: Pehle jee tha kya?\n',
#  'Hooda Iiit: Abhe mai kya puchra hu\n',
#  '+91 74407 00243: This message was deleted\n',
#  '+91 63779 49627: Abe Yash vardhan/yashwant , isko dhundho\n',
#  'Hooda Iiit: Ece football aaj joh joh aaya tha naam batao jaldi sabhke\n',
#  '+91 84012 00825: Sab dhundh rahe hai\nB wing me to nhi hai kahi\n',
#  'Hooda Iiit: 50 baar bolunga kya message dekhliya hai toh jawab deo na\n',
#  'Hooda Iiit: Naam toh batao ekbar kon kon gaya tha aaj football\n',
#  '+91 84012 00825: Me nhi tha\n',
#  'Hooda Iiit: Arey toh joh tha usko bol naam batae\n',
#  '+91 96961 53195: Uska roommate kon hai\n',
#  '+91 96961 53195: Ek 4th year ke bhaiya hai vo jante hai ..unse bat krta hu\n',
#  'Hooda Iiit: Haaa unka hi call aya tha\n',
#  'Hooda Iiit: Unko hi nahi milraha mat kar call\n',
#  '+91 96961 53195: Accha\n',
#  'Hooda Iiit: Mila kya\n',
#  'Lakshya Iiit: Aree vo yaha freshers hori hai i guess rgpv m usme gya hai shyd\n',
#  '+91 77278 13841: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/FSauqS5GvVNLyEZw7LsKu0\n',
#  '+91 77278 13841: Those who wanted to play cricket in rgpv. On sunday\n',
#  'Abhishek Iit B Ece: Plss all student come to mess.. \nSenior sir log aaye hai\n',
#  'Abhishek Iit B Ece: Come fast\n',
#  '+91 79853 07384: Aao saalo\n',
#  'govind mishra Iiit: All hostelers should report to Pranav sir in compound ASAP (within 5 mins)\n\nHe will be briefing about football practice tomorrow.\n',
#  '+91 89601 70220: Jaldi ! Jaldi! \n\nSabhi student 11 bje mess mein aa jao \n         Jaldi!!!!!\n',
#  'Vikas Iiit Cse Cr: Come ryt away\n',
#  'Abhinav Iiit: <Media omitted>\n',
#  'Abhinav Iiit: I am gonna forward this letter to office/administration\n',
#  'Abhinav Iiit: Is all problems mentioned?\n',
#  'Abhinav Iiit: If anything is missing\n',
#  'Abhinav Iiit: Will edit\n',
#  'Hooda Iiit: Bro thoda strictly likho tumlog\n',
#  'Hooda Iiit: Jabh paisa barabar derahe ho sabh facilities ka toh gusse me likho\n',
#  'Hooda Iiit: Asani se kaam nahi hoga warna\n',
#  'Abhinav Iiit: Jayada strictly nahin likhna chaiye kyunki\n',
#  'Abhinav Iiit: Situation reverse ho jayegi\n',
#  'Abhinav Iiit: I am taking seniors help\n',
#  'Hooda Iiit: Arey aise kaise hojaegi , abhi ek baat bata tum sabhke parents gusse me honge na\n',
#  "Abhinav Iiit: Don't worry\n",
#  'Hooda Iiit: Fir to hojaega\n',
#  'Abhinav Iiit: We need sympathy here\n',
#  'Abhinav Iiit: And seniors help also\n',
#  "Abhinav Iiit: So don't worry\n",
#  'Abhinav Iiit: I will try my best\n',
#  'Abhinav Iiit: Just support me\n',
#  'Hooda Iiit: <Media omitted>\n',
#  'Gaurav Baby Pink: Shi hai bhai good ...thora gym bhi add krde yr...tota phoota to hai hi.atleast dumbbells hi ajate ..\n',
#  '+91 98902 35487: Ha dumbells  chahiye\n',
#  'Abhinav Iiit: Pehele basic requirements try karte hain bhai\n',
#  'Abhinav Iiit: Agar mil gaya\n',
#  'Abhinav Iiit: Tho gym bhi puch lenge\n',
#  'Om South Iiit: Aare koi football grp ka link send karo\n',
#  'govind mishra Iiit: https://forms.gle/S5Xmweo7nZb7pZU7A\n\nInterest people for football fill this form\n',
#  'Om South Iiit: Yeh fill kardiya hei\n',
#  'Om South Iiit: Grp ka link bhejo\n',
#  'govind mishra Iiit: Ok link mai provide krwata hu\n',
#  'govind mishra Iiit: Thoda time do\n',
#  'Om South Iiit: Ok\n',
#  'govind mishra Iiit: https://chat.whatsapp.com/HRAPjCh4CrNHpC9EYv7Wj8\n',
#  'govind mishra Iiit: Done\n',
#  'Vikas Iiit Cse Cr: This message was deleted\n',
#  'Vikas Iiit Cse Cr: If anyone has lost their money in mess today,\nThey can contact me\n',
#  '+91 99733 25733: This message was deleted\n',
#  '+91 99733 25733: <Media omitted>\n',
#  '+91 63779 49627: https://chat.whatsapp.com/EkviA1eUVtLCRYira2F0MB\n',
#  'Bhuvan Cse: *New promotional Bharat Fiber Plan applicable in all SSAs of MP Circle*\nattractive Bharat  Fiber Plans applicable in all SSAs of MP Circle*\n\n\n*Fiber Basic Plus*: Fixed monthly charges: Rs.599\nSpeed up to 60 Mbps till 3300GB per month, up to 2Mbps beyond.\n24 hr unlimited free calling( Local+ STD)  to any network.\n\n *Fiber Value* :Fixed monthly charges: Rs.799, Speed: up to 100  Mbps till 3300GB per month, up to 2 Mbps beyond, 24 hr unlimited free calling( Local+ STD)  to any network\n\n*Super Star Premium –I*:Fixed monthly charges: Rs.749 , Speed: up to 100  Mbps till 1000GB per month, up to 5 Mbps beyond, Free bundled OTT Subscription –Sony LIV Premium,Zee5 Premium, Voot Select , Yupp TV Movies , Yupp TV FDFS ( First Day First Show), Yupp TV NCF Channels.\n24 hr unlimited free calling( Local+ STD)  to any network.\n\n*Super Star Premium –2* :Fixed monthly charges: Rs.949, Speed: up to 150  Mbps till 2000GB per month, up to 10 Mbps beyond, Free bundled OTT Subscription –Sony LIV Premium,Zee5 Premium, Voot Select , Yupp TV Movies , Yupp TV FDFS ( First Day First Show), Yupp TV NCF Channels.\n24 hr unlimited free calling( Local+ STD)  to any network, \n\n\n *Fiber Premium*:\nFixed monthly charges: Rs.999, Speed: up to 200  Mbps till 3300GB per month, up to 2 Mbps beyond, 24 hr unlimited free calling( Local+ STD)  to any network, Disney Hotstar Premium pack subscription without additional cost.\n\n *Fiber Ultra* :Fixed monthly charges: Rs.1499, Speed: up to 300  Mbps till 4000 GB per month, up to 4 Mbps beyond, 24 hr unlimited free calling( Local+ STD)  to any network, Disney Hotstar Premium pack subscription without additional cost.\n\n GST bill be charged extra.\n\n*OTT  Add –on pack*   having Sony LIV Premium,Zee5 Premium, Voot Select , Yupp TV Movies , Yupp TV FDFS ( First Day First Show), Yupp TV NCF Channels  available @ R.129 per month ( Including GST)  per customer.\n\n*Welcome Discount to  New Bharat Fiber   Broadband customers* : 90 % Discount maximum up to Rs.500 on first month Fixed monthly charges (FMC) in All  Bharat Fiber  broadband Plans  is available till 29-Jan-2022\n\nkindly take advantage of  attractive plans / offers and  book maximum number of new FTTH connections .\n',
#  'Bhuvan Cse: IIIT student ke group me share kar do\n',
#  'Vikas Iiit Cse Cr: Cricket bois come in the playground asap\n',
#  '+91 63779 49627: Hostel to pohonchne de bhai\n',
#  'Vikas Iiit Cse Cr: 2 bus aa chuki h vo aajao sb\n',
#  '+91 73850 97258: Basketball ball vala na\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Harsh Shivhare Iiit: Kll ka btaana ab\n',
#  'Vikas Iiit Cse Cr: After brkfast\n',
#  'Vishal Maurya ECE: If anyone have my broom 🧹🧹🧹 ( झाड़ू)  metal and plastic handle. Plz return it to A-38\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vishal Maurya ECE: 😶\u200d🌫️😶\u200d🌫️\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  'Punya Modi Iiit: Aryan Kamal Iiitb.vcf (file attached)\n',
#  'Punya Modi Iiit: Pls add him\n',
#  '+91 83829 29157: <Media omitted>\n',
#  'Hooda Iiit: Konsa maal fuka hai sabhne\n',
#  'Vikas Iiit Cse Cr added Nishant Bigshow\n',
#  'Vikas Iiit Cse Cr added +91 96941 29441\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  'Dev Iiit B Ece: Bhai videos isi group m send krna\n',
#  'Dev Iiit B Ece: Bss\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: This message was deleted\n',
#  '+91 99733 25733: <Media omitted>\n',
#  '+91 99733 25733: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  '+91 94154 46373: Baval video bhai👌🏻👌🏻hum log to dikh hi nahi rhe video me🛐\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  '+91 70078 75395: <Media omitted>\n',
#  'Labhanshu Meetha added Aditya Iiit Cse\n',
#  'Punya Modi Iiit: 9309855913 pls add this also\n',
#  'Aditya Iiit Cse: Aree mein ab aa gyaa\n',
#  'Vikas Iiit Cse Cr added Aditya Singh Flat\n',
#  '+91 98175 44050: volleyball ke liye kon kon chl rha h aaj manit\nek bar bta do\n',
#  '+91 98175 44050: us hisab se dekh lenge ki cab krni h ya bus se jana h\n',
#  'Gaurav Baby Pink: Cab costly hoti hai vaise bht\n',
#  'Gaurav Baby Pink: Seniors are hai koi ? Aise akele nahi ja skte hai na ?\n',
#  '+91 98175 44050: are 4 5 ho gye to 100 ya 50 lgenge sirf\n',
#  '+91 98175 44050: aaj trail h na message aya h\n',
#  'Hooda Iiit: Monday ka hai\n',
#  'Gaurav Baby Pink: Ye kab aya ?\n',
#  'Gaurav Baby Pink: Kaha?\n',
#  '+91 98175 44050: ok then\n',
#  '+91 86172 51132: Lunch aya kya?\n',
#  '+91 94154 46373: Haan\n',
#  'Likhit Kumar: Todays Session of First DYS\n🥳🥳🥳\n\nSpeaker : Nikhil Raj Sir\n                2022 Batch Passout\n                Placed in *Airtel* \nTime : 7:25 PM (Will start @7:30 PM Sharp)\n\nhttps://us02web.zoom.us/j/7613093607?pwd=bjVTc3RhaWlibVZNNEhXTzcwbnpJQT09\n\nID : 7613093607\nPass : 108\n\nWe will discuss about \n#Happiness\n#Time Management\n#Art of Smart Work\n',
#  "Likhit Kumar: Today evening we will have online session for all ...\n\nIt's compulsory for all participants...\n\nPlease be on time...\n\n*Nikhil Sir will give presentation*\nHe is working in Airtel and organised IIT PATNA camp for IIIT students \n😍😍😍\n",
#  "+91 93813 82523: Please join in the session senior sir told to me it's mandatory\n",
#  'Gaurav Baby Pink: Call kr kr ke bol rhe hai yr inform kro\n',
#  'Gaurav Baby Pink: Mai to khud hi outside hun\n',
#  'Gaurav Baby Pink: Inspire club is not compulsory yr ye log faltu me bol rhe hai merko lgra\n',
#  'Gaurav Baby Pink: Sunday ke din bhi inka inspire thodi attend krnge yr\n',
#  'Gaurav Baby Pink: 1 to chutti hai\n',
#  'Binod Iiit: 😅🤣\n',
#  '+91 83829 29157: Has anyone left his padlock in room no. A 20?\n',
#  'Vikas Iiit Cse Cr added +91 89858 44438\n',
#  '+91 93586 17312: <Media omitted>\n',
#  'Atif Iiit: <Media omitted>\n',
#  'Atif Iiit: <Media omitted>\n',
#  'Atif Iiit: <Media omitted>\n',
#  '+91 94154 46373: Haan dekha\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 91043 20838: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 98175 44050: kisi ke pass class me v type charger h?\n',
#  'Shubh Iiit It: Aryan Kamal Iiitb.vcf (file attached)\n',
#  'Shubh Iiit It: Add him\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Labhanshu Meetha added Aryan Kamal Iiit\n',
#  'Yash Scanner: https://chat.whatsapp.com/JvS43ILp1Qb6HiJG9GilbS\n',
#  'Yash Scanner: Physics group official👆\n',
#  'Yash Scanner: Sirf CSE and ECE(1-36) join krna\n',
#  'Birendra Bhai: 24 minutes lag gye kya type karne mai😂🧐\n',
#  'Hooda Iiit: \u200eOpen this link to join my WhatsApp Group: https://chat.whatsapp.com/HyBUVCZw1EPJgpTpVTC4ax\n',
#  'Hooda Iiit: This is an unofficial group so those who are interested in singing and those who know any musical instruments plz do join this group …. If this work we gonna make a band\n',
#  'govind mishra Iiit: *Freshers Jin Jin ko TT me Interest hai kal 1 bje td 206 me pahuch Jana*\n',
#  'Vikas Iiit Cse Cr added Anand Iiit\n',
#  'Binod Iiit: Follow this link to join my WhatsApp group: https://chat.whatsapp.com/E0ZQGI2KK5FJH9Qc5grxDk\n',
#  '+91 79034 07643: Sirf rgpv hostel walin ke liye hai kya?\n',
#  '+91 79034 07643: Walon*\n',
#  'Binod Iiit: Jo cricket m interested h un sab ke liye.\n',
#  'Abhinav Iiit: Anybody have HDFC credit card\n',
#  'Abhinav Iiit: If yes pls contact mohan\n',
#  'Abhinav Iiit: +916299536713\n',
#  '+91 98902 35487: For maharashtra   students,                  jinko bonafide chahiye vo mere ko apke names  se message karo  ki  muze bonafide chahiye...immediately\n',
#  '+91 89601 70220: Aman ECE ka new CR banega\n',
#  'Aman Iiit ECE: kon aman bhai\n',
#  'Birendra Bhai: Kisi ke siblings gandhi medical collage mai padhta hai kya\n',
#  'Birendra Bhai: ??\n',
#  'Om South Iiit: Haa kyun?\n',
#  'Om South Iiit: Siblings nhi hei...ek relative hei?\n',
#  'Himank Iiit: Kon aman\n',
#  '+91 62800 34870: Bhai mazak tha\n',
#  '+91 73850 97258: Dhattarwal\n',
#  '+91 98175 44050: alert _____\nbhai log seniors aa rhe h\nget in the hall\n',
#  '+91 98175 44050: call everyone if outside\n',
#  'Atif Iiit: Sab log niche aajao\n',
#  'Atif Iiit: Senior aarahe h\n',
#  'Vishal Maurya ECE: <Media omitted>\n',
#  '+91 84012 00825: Confirm??\n',
#  '+91 84012 00825: Vapis nhi hai na mazak??\n',
#  'Atif Iiit: <Media omitted>\n',
#  '+91 84012 00825: <Media omitted>\n',
#  'Abhinav Iiit: HELLO EVERYONE\nI AM PROUD TO ANNOUNCE THAT OUR IIIT BHOPAL IS GOING TO FORM A TEAM FOR OUR BELOVED GRAPHICS DESIGNERS,\nTHIS TEAM WILL GIVE YOU OPPORTUNITY TO PRACTICE AND LEARN YOUR SKILLS UNDER GUIDANCE OF YOUR SENIORS.\nWE WILL ASSIGN SOME POSITIONS AND WILL APPRECIATE THE WORK OF MEMBERS.\nINTERESTED STUDENTS CAN FILL THE FORM :\nhttps://forms.gle/iG3TXTFjgRcFfVee7\n',
#  'Abhinav Iiit: Recruitment for Film-Making and Photography Team\nThose who are interested in joining the Photography and Videography Team of IIIT Bhopal can fill this Form.\nForm Link : https://forms.gle/5zqeYziN6uvDzFHJ9\ndeadline : 20 November 2022\n',
#  'Abhinav Iiit: Recruitment for Video Editor\nThose who are interested in joining the Video Editing Team of IIIT Bhopal can fill this Form.\nDeadline : 20-Nov-2022\nForm Link : https://forms.gle/7Zs9TMrw5ZEcoq2dA\n',
#  '+91 93813 82523: https://docs.google.com/forms/d/e/1FAIpQLSe6RpcazshtML95_J-O4xaZyeOwlhyxcbgt2DWtfcCnt4U0CQ/viewform\n',
#  '+91 93813 82523: Join who are interested in photography and video editing\n',
#  '+91 93813 82523: Today 11PM is the deadline to fill this form\n',
#  '+91 98175 44050: important _______\nsuno bhai jo bhi valley ke trail ke liye gye the vo niche aa jao valley ke liye contribute krna h\n',
#  '+91 98175 44050: 10 min. me niche aa jao sare\n',
#  '+91 79853 07384: 6:30 neeche aa Jana meeting h\n',
#  '+91 98175 44050: suno sab\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 98175 44050: jo bhi volleyball ke liye gya tha apna apna nam scholar no. or room no. bhejo\n',
#  '+91 98175 44050: jo bhi nhi bhejega wo bahr ho jyega\n',
#  'Aman Iiit ECE: all students come near mess\n',
#  'Aman Iiit ECE: important meeting\n',
#  'Aman Iiit ECE: jaldi aao\n',
#  'Vishal Maurya ECE: Ok sir\n',
#  'Abhinav Iiit: Sab koi niche aa jaoi\n',
#  'Aman Iiit ECE: seniors are here\n',
#  'Aman Iiit ECE: come near mess immediately\n',
#  'Hentai IIIT: <Media omitted>\n',
#  'Hentai IIIT: vrist pehle bolna hai knist badme\n',
#  'Vikas Iiit Cse Cr: Every ECE student to stay in the cls after the faculty leave for CR election\n',
#  '+91 98902 35487: <Media omitted>\n',
#  'Labhanshu Meetha added Shubham Iiit B ECE\n',
#  '+91 99481 78169: Hi\n',
#  'Mohan Iiit: Oye apne batch ke saare football walo ko bol dena aaj practice hogi kit rkh le\n',
#  'Shubh Iiit It: Yes boss\n',
#  'Atif Iiit: Bhai answers dalo sab\n',
#  'Atif Iiit: Jisko milta hai\n',
#  'Hentai IIIT: <Media omitted>\n',
#  'Hentai IIIT: <Media omitted>\n',
#  '+91 94154 46373: <Media omitted>\n',
#  'Nobita IT: <Media omitted>\n',
#  'Gaurav Baby Pink: https://chat.whatsapp.com/DRSlj7aGKVJAAfNKoYrYuQ\n\nThose first year students which are interested in sports... Kindly join this group!!\n',
#  '+91 99733 25733: Hi guys\n*This side senior of 4th year CSE and student coordinator for your batch*\n\nJoin the group to know about the available online internship opportunities from 1st year and further\n\n_https://chat.whatsapp.com/EAT0naKFyptFTZTowf8pvU_\n\n*NOTE: Webinar will be conducted today at sharp 7:00pm. Kindly join the webinar*\n',
#  'Vikas Iiit Cse Cr: https://chat.whatsapp.com/JvS43ILp1Qb6HiJG9GilbS\nPhysics official grp cse + ece 1-36\n',
#  'Abhinav Iiit: Hi guys\n*This side senior of 4th year CSE and student coordinator for your batch*\n\nJoin the group to know about the available online internship opportunities from 1st year and further\n\n_https://chat.whatsapp.com/JH0TC5uGrNC7O2PCrT6wFZ_\n\n*NOTE: Webinar will be conducted today at sharp 7:00pm. Kindly join the webinar*\n',
#  'Labhanshu Meetha added Govind Maggu Iiit\n',
#  'Vikas Iiit Cse Cr: https://chat.whatsapp.com/I3yLgxZiDb7623ansMUyLZ\n',
#  "+91 95849 44475 joined using this group's invite link\n",
#  "+91 63776 10208 joined using this group's invite link\n",
#  "+91 99935 37646 joined using this group's invite link\n",
#  "+91 93058 65532 joined using this group's invite link\n",
#  "Aditya Maya joined using this group's invite link\n",
#  "+91 72230 86207 joined using this group's invite link\n",
#  "+91 73884 04311 joined using this group's invite link\n",
#  "Ronak Iiit joined using this group's invite link\n",
#  "+91 63060 27910 joined using this group's invite link\n",
#  "Vidushi Iiit joined using this group's invite link\n",
#  "+91 83059 17052 joined using this group's invite link\n",
#  "Punya Modi Iiit: ⭐️Greetings from *1Stop.ai* \n\n*Looking for internship but Don't know ❓when to build up your career and from where give a kickstart to your career in technical and non technical filed with us!*\n\n🎓 Get Ready for a career\n🎓 Learn the Latest Skills from industry \n🎓 Earn Certification from industry\n🎓Track your growth\n🎓Be industrial ready \n🎓work with Industrial Mentors\n\n⭐️Intersted Students join the whatsapp group for such more information via below link:\n➡️ *Whatsapp Group Link* : \nhttps://chat.whatsapp.com/LpH2X2IowY0K1D5XcYPjz2\n\n*Note: THIS WHATSAPP GROUP LINK WILL BE ACTIVE TILL 7 PM NOON*💫\n\n➡️1Stop.ai in association with *Techniche, (IIT Guwahati)* brings you an exclusive internship opportunity to students in different domains & fields.\n",
#  "+91 97938 43104 joined using this group's invite link\n",
#  "+91 72077 22009 joined using this group's invite link\n",
#  "+91 79860 87505 joined using this group's invite link\n",
#  "+91 77429 05588 joined using this group's invite link\n",
#  "+91 96820 01652 joined using this group's invite link\n",
#  "+91 83189 46679 joined using this group's invite link\n",
#  "+91 70895 59951 joined using this group's invite link\n",
#  "+91 95251 13211 joined using this group's invite link\n",
#  "+91 91092 08846 joined using this group's invite link\n",
#  "+91 62618 38101 joined using this group's invite link\n",
#  'Gaurav Baby Pink: https://chat.whatsapp.com/I3yLgxZiDb7623ansMUyLZ\n',
#  "+91 79999 36731 joined using this group's invite link\n",
#  'Gaurav Baby Pink: Everyone have to join this grp\n',
#  "+91 81098 77675 joined using this group's invite link\n",
#  "+91 99776 87351 joined using this group's invite link\n",
#  "+91 87178 10796 joined using this group's invite link\n",
#  "+91 76939 35712 joined using this group's invite link\n",
#  "+91 62684 47780 joined using this group's invite link\n",
#  "+91 97525 75930 joined using this group's invite link\n",
#  "+91 90447 49188 joined using this group's invite link\n",
#  "+91 76720 05445 joined using this group's invite link\n",
#  'Abhinav Iiit: There is no gt tmrw\n',
#  'Abhinav Iiit: Maximum strength should be present tomorrow\n',
#  "+91 89552 72456 joined using this group's invite link\n",
#  "+91 96912 57483 joined using this group's invite link\n",
#  "+91 97735 73381 joined using this group's invite link\n",
#  "+91 73381 76710 joined using this group's invite link\n",
#  "+91 82258 47505 joined using this group's invite link\n",
#  "+91 88394 42949 joined using this group's invite link\n",
#  'Vishal Maurya ECE: Kisine Mera parcel liya hai kya, usme kapde the\n',
#  "+91 72509 27506 joined using this group's invite link\n",
#  "+91 81202 43729 joined using this group's invite link\n",
#  "+91 84680 96990 joined using this group's invite link\n",
#  'Hooda Iiit: Ece ka CR kon hai ?\n',
#  'Hooda Iiit: Cs wali class me\n',
#  "+91 70005 21814 joined using this group's invite link\n",
#  'Shubham Iiit B ECE: Aditya\n',
#  'Hooda Iiit: Okay\n',
#  'Vishal Maurya ECE: ...\n',
#  'Vishal Maurya ECE: ??\n',
#  '+91 83189 46679: Hii\n',
#  'Vishal Maurya ECE: Kisine Mera parcel liya hai kya, usme kapde the\n',
#  'Vishal Maurya ECE: A38 me leke aa ja bsdk, jisne bhi liya hai\n',
#  'Lakshya Iiit: Kyu kya hua\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 94216 64615: Aaj Mera parcel aaya tha 5-6 baje\nKisine liya hai to b-19 mai deliver kar do\n',
#  "Gaurav Iiit It joined using this group's invite link\n",
#  "+91 74897 15695 joined using this group's invite link\n",
#  "Risha IIIT joined using this group's invite link\n",
#  "+91 70491 87901 joined using this group's invite link\n",
#  "+91 95735 14014 joined using this group's invite link\n",
#  "+91 90985 09973 joined using this group's invite link\n",
#  "+91 92296 96556 joined using this group's invite link\n",
#  "+91 94242 60162 joined using this group's invite link\n",
#  "+91 98932 21960 joined using this group's invite link\n",
#  "Uday Jammant joined using this group's invite link\n",
#  "+91 95618 78909 joined using this group's invite link\n",
#  "+91 79094 66897 joined using this group's invite link\n",
#  "+91 79860 87505: Rgpv hostler who want to play cricket today in rgpv ground type 'yes'(for no. of student count.)\n",
#  '+91 77278 13841: Yes\n',
#  '+91 89552 72456: Yes\n',
#  'Nihar Neta: Yes\n',
#  '+91 90598 23725: Yes\n',
#  '+91 63776 10208: Yes\n',
#  'Aryaman Iiit: Yes\n',
#  '+91 63776 10208: Yes\n',
#  '+91 73850 97258: Yes\n',
#  '+91 72230 86207: Yes\n',
#  '+91 63060 27910: Yes\n',
#  'Aman Iiit ECE: yes\n',
#  'Aditya Maya: Yes\n',
#  'Aryan Kamal Iiit: yes 🧐\n',
#  'Om South Iiit: Yes\n',
#  'Labhanshu Meetha: tu toh ghar  gya hai na\n',
#  "+91 63062 57655 joined using this group's invite link\n",
#  'Bhuvan Cse: Yes\n',
#  '+91 70078 75395: Yes\n',
#  '+91 98175 44050: yes\n',
#  '+91 77818 08201: Yes\n',
#  'Aman Iiit ECE: anything for cricket\n',
#  '+91 79860 87505: 4:30 tym \nPress ok for confirmation\n',
#  '+91 89601 70220: Nasta aa gya\n',
#  "+91 73988 92099 joined using this group's invite link\n",
#  'Puru Arora CSE added +91 90500 95959\n',
#  '+91 93813 82523: <Media omitted>\n',
#  '+91 93813 82523: https://forms.gle/9So8gEgjnPC7B4b56\n',
#  '+91 93813 82523: For any queries contact below number in the photo\n',
#  'Atif Iiit: Kon kon jayega\n',
#  '+91 95849 44475: This message was deleted\n',
#  '+91 95849 44475: 👍\n',
#  '+91 95849 44475: <Media omitted>\n',
#  '+91 95849 44475: Mai rehta hu whi pass me b\n',
#  '+91 95849 44475: H\n',
#  'Gaurav Baby Pink: Yeh isckon related sb purely choice hai ..kuch bhi compulsory nahi hai ..\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Dev Iiit B Ece: null\n',
#  'Bhuvan Cse: Cse me 30 31 roll no. Kiska haii ??\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  '+91 79853 07384: Yes\n',
#  'Atif Iiit: Bhai Mera naam hé ni h\n',
#  'Shubham Iiit B ECE: https://ffe.org/amazon-future-engineer/\n',
#  'Shubham Iiit B ECE: *For girls*\n',
#  'Shubham Iiit B ECE: Koi girl-friend ho toh suggest kr do\n',
#  'Dev Iiit B Ece: 🥲🥲\n',
#  '+91 86172 51132: <Media omitted>\n',
#  '+91 96961 53195: Koi ni Bhai vinod ki mar liya kr 😌\n',
#  'Atif Iiit: 😂😂😂\n',
#  'Binod Iiit: Chak raaand madrchod\n',
#  'Shubham Iiit B ECE: <Media omitted>\n',
#  'Atif Iiit: Ladki ni Mili toh ladka he sahi bhen chod 😂\n',
#  'Binod Iiit: This message was deleted\n',
#  '+91 63779 49627: Ye bhi thik h 😌\n',
#  'Binod Iiit: Bhai ladkiya bhi is gp m faltu ki baaten khatm karo.\n',
#  '+91 63779 49627: 😌\n',
#  '+91 63779 49627: Itni achi gaaliya Mt Diya kro yaar , thoda paarivarik  mahol bnao 😌\n',
#  '+91 96961 53195: Try krte hai 😌\n',
#  'Atif Iiit: Tu try bahut Karta h … kam kiya kr try\n',
#  '+91 96961 53195: Hn hn 😂\n',
#  'Rishit Iiit IT: Bhai koi headphone girvi pe de sakta hai kya?\n',
#  '+91 96961 53195: Kya dega girvi me\n',
#  'Rishit Iiit IT: Apni gand Dede girvi mai\n',
#  'Nid Timepass: Rate Kitna hain 1 ghante ka\n',
#  'Atif Iiit: Tu Gand bhi deta hai Kay ?\n',
#  '+91 96961 53195: Bhai sb Teri tarah nhi hote\n',
#  'Binod Iiit: Bhai girvi tujhe Dena h agr headphone lena h to\n',
#  'Rishit Iiit IT: Tu ghar ja yaar\n',
#  'Rishit Iiit IT: Sabki nahi teri baat ho rahi hai😂\n',
#  'Atif Iiit: @919696153195 Tu happy ending bhi deta hai Kay 😂\n',
#  "Abhinav Iiit: Hey folks,\n\nGDSC is back again with a great session on Web3.\n\nIf you are willing to explore web3. This is the best opportunity.\n\nSession Agenda:\n1. Introduction to Web3 space.\n2. Importance of web3\n3. Web2 vs Web3\n4. Transition from web2 to web3\n5. Where to find opportunities in web3\n6. Practical advice to future proof your career in web3.\n\n\nDate: 28 Nov 2022\nTime: 6:30 PM\nDuration: 1 Hour\nRSVP Link : https://gdsc.community.dev/e/m9nbs3/\n\nDon't forget to RSVP!!!\n",
#  'Rishit Iiit IT: <Media omitted>\n',
#  '+91 96961 53195: Abe chup rho..meri side ho tum 😂\n',
#  'Atif Iiit: Yeh kab hua or humko khabar tak na hue 🌚\n',
#  '+91 96961 53195: Ho gya bs 😌\n',
#  'Rishit Iiit IT: Bs bs\n',
#  'Rishit Iiit IT: Chalo so jao\n',
#  'Atif Iiit: Chill Bhai Bas maje le rahe the … don’t mind dude\n',
#  '+91 96961 53195: Hn chlo good night 😌\n',
#  '+91 63779 49627: Mind kr bhi lega to kya ukhaad lega 😂\n',
#  '+91 96961 53195: Tum chacha ke Ghar me ho to vahi raho ya nhi 😂\n',
#  '+91 63779 49627: M vha hota to tu itni bkwas ni kr rha hota 😌\n',
#  "+91 79821 33543 joined using this group's invite link\n",
#  '+91 91182 31995: Mess m kisi k paise gire h kya bhai\n',
#  'Aditya Pandey IT: Ha bhai\n',
#  'Aditya Pandey IT: This message was deleted\n',
#  'Aditya Singh Flat: This message was deleted\n',
#  'Atharv Iiit: Khana kha lo jisne nhi khaya\n',
#  '+91 73381 76710: <Media omitted>\n',
#  '+91 70675 28948: Mess me khana sirf 10 min ke liye hai aur\n',
#  "Pratham Flat Cse joined using this group's invite link\n",
#  '+91 83189 46679: Chai aayi hai\n',
#  '+91 83189 46679: Mess mein\n',
#  'Arth Iiit: Aur noodle bhi honge na\n',
#  '+91 83189 46679: Means mess start hua ki nhi\n',
#  '+91 96961 53195: Ho gya\n',
#  'Pratham Flat Cse: Khana aa gya\n',
#  'Pratham Flat Cse: ?\n',
#  'Nihar Neta: Aaja Mere room m kha lena\n',
#  '+91 63779 49627: Aajao saare , malai koffte in the mess bois\n',
#  'Shubham Iiit B ECE: https://ig.me/j/AbbHstnI7JW2HVQc/\n',
#  'Shubham Iiit B ECE: Instagram group....\n',
#  'Vikas Iiit Cse Cr: This message was deleted\n',
#  'Shubham Iiit B ECE: Kiska username ?\n',
#  'Vikas Iiit Cse Cr: This message was deleted\n',
#  'Binod Iiit: <Media omitted>\n',
#  'Gaurav Baby Pink added +91 81257 28837\n',
#  '+91 81257 28837: Jk\n',
#  'Aditya Iiit: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: This message was deleted\n',
#  'Gaurav Baby Pink: This message was deleted\n',
#  '+91 90500 95959: Sbi bank for scholarship roll 56 and 64 CSE IMP. ACCOUNT OPENING LATE DATE\n',
#  "+91 93813 82523: Hey folks,\n\nGDSC is back again with a great session on Web3.\n\nIf you are willing to explore web3. This is the best opportunity.\n\nSession Agenda:\n1. Introduction to Web3 space.\n2. Importance of web3\n3. Web2 vs Web3\n4. Transition from web2 to web3\n5. Where to find opportunities in web3\n6. Practical advice to future proof your career in web3.\n\n\nDate: 28 Nov 2022\nTime: 6:30 PM\nDuration: 1 Hour\nRSVP Link : https://gdsc.community.dev/e/m9nbs3/\n\nDon't forget to RSVP!!!\n",
#  '+91 93813 82523: https://teams.microsoft.com/l/meetup-join/19%3aoOK69GxV4OQG-xa8Dp9qhetgrgPO6oL8gQsitHPPYEQ1%40thread.tacv2/1669361015371?context=%7b%22Tid%22%3a%22161a86cc-cc0c-4622-b590-d0b92db751fe%22%2c%22Oid%22%3a%2270ab63e4-7573-4d1c-83ba-aafbe0c79bae%22%7d\n',
#  'Abhinav Iiit: https://teams.microsoft.com/l/meetup-join/19%3aoOK69GxV4OQG-xa8Dp9qhetgrgPO6oL8gQsitHPPYEQ1%40thread.tacv2/1669361015371?context=%7b%22Tid%22%3a%22161a86cc-cc0c-4622-b590-d0b92db751fe%22%2c%22Oid%22%3a%2270ab63e4-7573-4d1c-83ba-aafbe0c79bae%22%7d\n',
#  '+91 90447 49188: Join fast everyone\n',
#  'Atif Iiit: Koi bahar Gaya hai\n',
#  'Atif Iiit: Toh practical file la de\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 83829 29157: <Media omitted>\n',
#  '+91 93813 82523: <Media omitted>\n',
#  '+91 93813 82523: These students contact anuj sir for bona-fide certificate  and other certificates\n',
#  '+91 93813 82523: Mr Anuj Sir Iiit Bhopal N.vcf (file attached)\n',
#  '+91 93813 82523: Anuj sir contact number\n',
#  '+91 95849 44475: <Media omitted>\n',
#  '+91 95849 44475: <Media omitted>\n',
#  'Atif Iiit: Ek chiz samaj me ni aae toh puch sakte hai but agar pura he ni aae then 🤣\n',
#  '+91 70005 21814: Then just😴😴😴in class\n',
#  '+91 95849 44475: Right\n',
#  'Atif Iiit: Marks Tu dega bsdk 🥲\n',
#  '+91 95849 44475: Ye bhi shi h😂\n',
#  '+91 70005 21814: Samajh aa nhi rha baki kya ghanta score krega ?\n',
#  'Atif Iiit: Last min formula bruh 😏\n',
#  '+91 70005 21814: 👍\n',
#  '+91 93813 82523: <Media omitted>\n',
#  '+91 93813 82523: These people collect their  identity cards\n',
#  "+91 73850 97258: Hello Everyone, \n\n*I request everyone in the group to kindly circulate the below link to all your mates in other classes and ask them to join the group so they wouldn't miss out the opportunity*\n\n*https://chat.whatsapp.com/H6vSXrKNXIKAwKxI3dZen0*\n\n*RESPECTIVE CR'S and classmates NEED TO ENSURE EVERYONE ARE IN GROUP IN SHORT TIME*\n",
#  'Gaurav Baby Pink: IIIIT Boys hostel issue regarding 40 rgpv students entering our hostel with evacuation of 20 rooms and sharing our already limited resources with other college students has affected me .\n',
#  'Gaurav Baby Pink: I had taken the issue seriously and tried all methods ,but the final decision regarding it is not in our favour and we  will have to share this hostel ( not our hostel anymore) with rgpv students.\n',
#  "Gaurav Baby Pink: .today 40 students are entering tomorrow 100 will ...there's no stopping.\n",
#  "Gaurav Baby Pink: Faculty members, student council, president 4th yr ,seniors ,I have tried talking to everyone to resolve the issue but all have said the same thing directly or indirectly that they can't do anything and we will have to adjust with rgpv students only or leave the hostel,take refund\nChoice is ours ,\n",
#  "Gaurav Baby Pink: So , If as a CR i can't even save our hostel which is like our second home i don't feel right to represent the  students as a CR.\n",
#  'Gaurav Baby Pink: Thus I am stepping down from CR CSE .\n',
#  'Gaurav Baby Pink: Re elections will take place again in class only, giving all equal chances to become CR CSE.\n',
#  'Gaurav Baby Pink: Gaurav Mamgain\n1st yr CSE\n',
#  '+91 83189 46679: This message was deleted\n',
#  '+91 84012 00825: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  '+91 73850 97258: <Media omitted>\n',
#  'Vishal Maurya ECE: This message was deleted\n',
#  '+91 83189 46679: 🤦\u200d♂️\n',
#  'Shubham Iiit B ECE: This message was deleted\n',
#  'Shubham Iiit B ECE: <Media omitted>\n',
#  "+91 93813 82523: Today onwards wearing identity card is mandatory and no one student didn't go to sports complex this is the msg from our senior sirs\n",
#  '+91 93813 82523: <Media omitted>\n',
#  '+91 98175 44050: cs batch 6 me kon kon h\n',
#  '+91 84012 00825: Me🙃\nPrathmesh\nSachinandan\nAtul\n',
#  'Atif Iiit: This message was deleted\n',
#  'Shubham Iiit B ECE: <Media omitted>\n',
#  'Rahul Iiit: <Media omitted>\n',
#  'Rahul Iiit: Ultra sakht🫡\n',
#  '+91 94216 64615: This message was deleted\n',
#  'Atif Iiit: <Media omitted>\n',
#  'Atif Iiit: 🫥\n',
#  '+91 84012 00825: Tum grp 6 me nhi ho\n7 me ho😐\n',
#  '+91 70005 21814: Those who have not submitted their library form must submit their forms untill tomorrow i.e.2Dec.\n',
#  '+91 83189 46679: Cs students come to TC 101\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  'Vishal Maurya ECE: This message was deleted\n',
#  'Vishal Maurya ECE: This message was deleted\n',
#  '+91 83189 46679: Has anyone lost key contact me\n',
#  '+91 74407 00243: <Media omitted>\n',
#  '+91 96961 53195: <Media omitted>\n',
#  '+91 96961 53195: This message was deleted\n',
#  '+91 96961 53195: This message was deleted\n',
#  'Rishit Iiit IT: This message was deleted\n',
#  'Abhinav Iiit: https://docs.google.com/forms/d/e/1FAIpQLSdePx-epKvsVuR2LU5uGMpFF8FgxESubAV1H4zlYyB2cnZbgQ/viewform?usp=sf_link\n',
#  'Abhinav Iiit: Who are interested in basketball pls fill this form\n',
#  '+91 93813 82523: https://docs.google.com/forms/d/e/1FAIpQLSdePx-epKvsVuR2LU5uGMpFF8FgxESubAV1H4zlYyB2cnZbgQ/viewform?usp=sf_link\n\n\nWho are interested in basketball pls fill this form\n',
#  'Vikas Iiit Cse Cr: <Media omitted>\n',
#  'Vikas Iiit Cse Cr: Room no. TC 102\n',
#  'Vikas Iiit Cse Cr: Rescheduled today again\nCome in TC 102 right now\n',
#  'Atif Iiit: B wing me WiFi kisko chaiye\n',
#  '+91 83189 46679: This message was deleted\n',
#  '+91 83189 46679: This message was deleted\n',
#  'Atif Iiit: Make a group and collect money\n',
#  '+91 83189 46679: This message was deleted\n',
#  '+91 83189 46679: This message was deleted\n',
#  'Atif Iiit: Kisko ?\n',
#  '+91 83189 46679: This message was deleted\n',
#  'Atif Iiit: Bhai ho Gaya fir toh\n',
#  'Atif Iiit: Kn hone wala h\n',
#  'govind mishra Iiit: Kisi ko ek black wristband mila kahi?\n',
#  'Labhanshu Meetha added Kanak Iiit\n',
#  'Abhinav Iiit: Om \nVenky \nAryan \nVikas \nGaurav \nYash bhardwaj\n',
#  'Abhinav Iiit: Mess committee\n',
#  'Abhishek Iit B Ece: https://docs.google.com/forms/d/e/1FAIpQLSeFlOndhmLvk6FQrUwJbzNF_dOPT5wzFPfwo1_y3HIUEDM1xw/viewform?usp=sf_link\n',
#  'Abhinav Iiit: https://chat.whatsapp.com/I3yLgxZiDb7623ansMUyLZ\n',
#  '+91 94516 98019: <Media omitted>\n',
#  '+91 93813 82523: https://forms.gle/LULqRiFbyWw2yqAb6\n',
#  '+91 93813 82523: Who are not in the inspire club kindly fill this form\n',
#  'Aman Iiit ECE: kal bhopal gas tragedy ki holiday hai kya\n',
#  'Rishit Iiit IT: Bhai college walo ko farak hi nahi padta yaaar😭\n',
#  "+91 93813 82523: Yesterday's Web Development PDF shared by  *NIKHIL RATHORE SIR*\n👉https://docs.google.com/document/d/1WuFh6mMSo-Xji-Mk36Zt3JqVXfXRKUPJySVccW0jtBA/edit?usp=drivesdk\n",
#  '+91 93813 82523: Yesterday session pdf\n',
#  'Abhinav Iiit: https://cuvette.tech/app/student/login/?type=register&referralCode=THUEXL\nyou can start looking at remote internships \ni.e. what skill sets they want and from here you can start working on it \n(applying for these internships right now is not recommended)\nit is just to let you all know about various tech stack required in market\n',
#  '+91 91258 29620: <Media omitted>\n',
#  '+91 91258 29620: <Media omitted>\n',
#  '+91 91258 29620: <Media omitted>\n',
#  '+91 83189 46679: ?\n',
#  '+91 81202 43729: This message was deleted\n',
#  '+91 83829 29157: Does anybody want to play badminton?\n',
#  '+91 83829 29157: Come along with racquet.\n',
#  'Abhinav Iiit: 😂😂\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  'Shubham Iiit B ECE: This message was deleted\n',
#  'Aryaman Iiit: https://www.hindustantimes.com/india-news/free-mein-khana-khaya-mba-student-gatecrashes-wedding-washes-dishes-in-viral-video-101669941556514-amp.html\n\nBach ke rehna bhai\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  '+91 96820 01652: bhai akele akele🥲\n',
#  '+91 96820 01652: how shame is this\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  'Dev Iiit B Ece: <Media omitted>\n',
#  'Yash Scanner: null\n',
#  'Vikas Iiit Cse Cr: Anyone who is outside of rgpv at the moment ,do call me\n',
#  '+91 63779 49627: Pitthu khelna h jis jisko vo rgpv hall me aajo niche\n',
#  'Nobita IT: <Media omitted>\n',
#  'Mohan Iiit: Everyone to be present in basketball ground of rgpv for cricket trials by 9\n',
#  'Aditya Maya: Bhai koi basketball court aa rha ho to ek copy aur pen lete aana...seniors ne magaya hai\n',
#  'Mohan Iiit: 2 nd section should come now to the above mentioned venue\n',
#  'Mohan Iiit: All should carry their water bottles\n',
#  'Mohan Iiit: Should reach within 10 min\n',
#  '+91 93813 82523: Wearing shoes is mandatory who are coming to cricket trails the students who want to come ground for cricket trails please wear the shoe\n',
#  'Madhav Iiit: Jaldi aa jao\n',
#  'Madhav Iiit: Selection khatan hone wale hai\n',
#  'Dev Iiit B Ece: This message was deleted\n',
#  '+91 62618 38101: Day scholar ka ni hoga kya\n',
#  '+91 63060 27910: Please can anyone share the full adress of RGPV ( IIIT boys hostel ).....\n',
#  '+91 94516 98019: IIIT bhopal Boys Hostel(C.V. RAMAN),Rajiv gandhi proudyogiki vishwavidyala(RGPV),bhopal\nairport By-pass road, Gandhinagar ,BHOPAL\n',
#  '+91 84680 96990: 😁\n',
#  '+91 63060 27910: Pincode.?\n',
#  ...]

# %%
dates = re.findall(date_pattern,data)

# %%
df = pd.DataFrame({"date":dates,"message":messages})
df
# Out:
#                   date                                            message
# 0      09/11/22, 21:35  Messages and calls are end-to-end encrypted. N...
# 1      05/11/22, 21:48  Labhanshu Meetha created group "Iiit unofficia...
# 2      09/11/22, 21:35                       Labhanshu Meetha added you\n
# 3      09/11/22, 21:35             Labhanshu Meetha added Protien Iiitb\n
# 4      09/11/22, 21:36           Labhanshu Meetha added +91 99733 25733\n
# ...                ...                                                ...
# 22575  04/10/24, 21:31                 Punya Modi Iiit: <Media omitted>\n
# 22576  04/10/24, 21:37  Punya Modi Iiit: 🚀 Join Axios Club – Become a ...
# 22577  06/10/24, 13:10  +91 98175 44050: Indian Institute Of Informati...
# 22578  06/10/24, 13:14  +91 98175 44050: guys do apply in it. It is to...
# 22579  06/10/24, 18:02  Punya Modi Iiit: Reminder: The form closes at ...
#
# [22580 rows x 2 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
# /var/folders/hz/5f5vbq1x2f946nh8dq84fyc80000gn/T/ipykernel_21810/1621113520.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date'] = pd.to_datetime(df['date'])
#                      date                                            message
# 0     2022-09-11 21:35:00  Messages and calls are end-to-end encrypted. N...
# 1     2022-05-11 21:48:00  Labhanshu Meetha created group "Iiit unofficia...
# 2     2022-09-11 21:35:00                       Labhanshu Meetha added you\n
# 3     2022-09-11 21:35:00             Labhanshu Meetha added Protien Iiitb\n
# 4     2022-09-11 21:36:00           Labhanshu Meetha added +91 99733 25733\n
# ...                   ...                                                ...
# 22575 2024-04-10 21:31:00                 Punya Modi Iiit: <Media omitted>\n
# 22576 2024-04-10 21:37:00  Punya Modi Iiit: 🚀 Join Axios Club – Become a ...
# 22577 2024-06-10 13:10:00  +91 98175 44050: Indian Institute Of Informati...
# 22578 2024-06-10 13:14:00  +91 98175 44050: guys do apply in it. It is to...
# 22579 2024-06-10 18:02:00  Punya Modi Iiit: Reminder: The form closes at ...
#
# [22580 rows x 2 columns]

# %%
users=[]
msg=[]

for i in df['message']:
    entry = re.split(r'([\w\W]+?):\s',i)
    if entry[1:]:
        users.append(entry[1])
        msg.append(entry[2])
    else:
        users.append('group notification')
        msg.append(entry[0])
df['user_name'] = users
df['user_msg'] = msg
df.drop(columns=['message'],inplace=True)

# %%
df.sample(10)
# Out:
#                      date           user_name  \
# 8052  2023-01-29 20:42:00     +91 98902 35487
# 6035  2022-12-31 01:08:00     +91 84012 00825
# 2219  2022-10-12 17:51:00     +91 70000 19109
# 13959 2023-12-05 00:40:00  govind mishra Iiit
# 10904 2023-02-28 18:28:00     +91 70176 14074
# 9620  2023-02-21 21:41:00          Nihar Neta
# 8740  2023-10-02 20:38:00   Vishal Maurya ECE
# 18906 2023-09-26 13:37:00         Madhav Iiit
# 12162 2023-03-18 23:46:00     +91 75056 16125
# 19219 2023-10-17 17:18:00     Punya Modi Iiit
#
#                                                 user_msg
# 8052                                   <Media omitted>\n
# 6035   Jarur jarur\nMaths wlae grp me dalke shuruat k...
# 2219   Vikas bro jldi jldi mini khatam karwa do firr ...
# 13959                                    Kha aaya msg?\n
# 10904                       99 percent attendance rakh\n
# 9620                            Puri march gt krte hai\n
# 8740                          This message was deleted\n
# 18906                                               To\n
# 12162  Hain to dono animation hi , AltBalaji Dekha ka...
# 19219                   Happy Birthday @919229696556 🎉\n

# %%
df['year'] = df['date'].dt.year
df['month_name'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

# %%
df['user_name'].value_counts().index
# Out:
# Index(['+91 84012 00825', '+91 99096 93021', 'govind mishra Iiit',
#        '+91 70078 75395', 'Vikas Iiit Cse Cr', '+91 94154 46373',
#        '+91 63779 49627', 'Gaurav Baby Pink', '+91 74407 00243',
#        '+91 70608 54113',
#        ...
#        '+91 88269 17687', '+91 89571 17749', '+91 95735 14014',
#        '+91 63930 37184', '+91 88394 42949', '+91 82007 57692',
#        '+91 95846 26278', '+91 79094 66897', '+91 95949 54822',
#        '+91 73891 12333'],
#       dtype='object', name='user_name', length=221)

# %%
df[df['user_msg']=='<Media omitted>\n'].shape[0]
# Out:
# 2354

# %%
# !pip3 install urlextract
# Out:
# Requirement already satisfied: urlextract in ./.venv/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from urlextract) (3.10)
# Requirement already satisfied: uritools in ./.venv/lib/python3.12/site-packages (from urlextract) (4.0.3)
# Requirement already satisfied: platformdirs in ./.venv/lib/python3.12/site-packages (from urlextract) (4.3.6)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from urlextract) (3.16.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from urlextract import URLExtract

extract = URLExtract()
urls=[]
for i in df['user_msg']:
    urls.extend(extract.find_urls(i))
print(len(urls))
# Out:
# 293

# %%
top_user = df['user_name'].value_counts().head().index
top_msg = df['user_name'].value_counts().head().values

# %%
# import matplotlib.pyplot as plt
# !pip3 install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
ax.bar(top_user,top_msg)
# plt.xticks(rotaion='vertical')
# Out:
# <BarContainer object of 5 artists>

# %%
df['month'] = df['date'].dt.month

# %%
df
# Out:
#                      date           user_name  \
# 0     2022-09-11 21:35:00  group notification
# 1     2022-05-11 21:48:00  group notification
# 2     2022-09-11 21:35:00  group notification
# 3     2022-09-11 21:35:00  group notification
# 4     2022-09-11 21:36:00  group notification
# ...                   ...                 ...
# 22575 2024-04-10 21:31:00     Punya Modi Iiit
# 22576 2024-04-10 21:37:00     Punya Modi Iiit
# 22577 2024-06-10 13:10:00     +91 98175 44050
# 22578 2024-06-10 13:14:00     +91 98175 44050
# 22579 2024-06-10 18:02:00     Punya Modi Iiit
#
#                                                 user_msg  year month_name  \
# 0      Messages and calls are end-to-end encrypted. N...  2022  September
# 1      Labhanshu Meetha created group "Iiit unofficia...  2022        May
# 2                           Labhanshu Meetha added you\n  2022  September
# 3                 Labhanshu Meetha added Protien Iiitb\n  2022  September
# 4               Labhanshu Meetha added +91 99733 25733\n  2022  September
# ...                                                  ...   ...        ...
# 22575                                  <Media omitted>\n  2024      April
# 22576                                                     2024      April
# 22577                                                     2024       June
# 22578  guys do apply in it. It is totally free of cost\n  2024       June
# 22579                                                     2024       June
#
#        day  hour  minute  month
# 0       11    21      35      9
# 1       11    21      48      5
# 2       11    21      35      9
# 3       11    21      35      9
# 4       11    21      36      9
# ...    ...   ...     ...    ...
# 22575   10    21      31      4
# 22576   10    21      37      4
# 22577   10    13      10      6
# 22578   10    13      14      6
# 22579   10    18       2      6
#
# [22580 rows x 9 columns]

# %%
timeline = df.groupby(['year','month','month_name']).count()['user_msg'].reset_index()

# %%
timeline
# Out:
#     year  month month_name  user_msg
# 0   2022      1    January        27
# 1   2022      2   February        11
# 2   2022      3      March        25
# 3   2022      4      April        25
# 4   2022      5        May        72
# 5   2022      6       June        34
# 6   2022      7       July        24
# 7   2022      8     August       241
# 8   2022      9  September       818
# 9   2022     10    October       108
# 10  2022     11   November      1015
# 11  2022     12   December      3696
# 12  2023      1    January      1952
# 13  2023      2   February      2569
# 14  2023      3      March      1450
# 15  2023      4      April       863
# 16  2023      5        May       996
# 17  2023      6       June       775
# 18  2023      7       July       731
# 19  2023      8     August      1727
# 20  2023      9  September      1177
# 21  2023     10    October       880
# 22  2023     11   November       454
# 23  2023     12   December       865
# 24  2024      1    January       274
# 25  2024      2   February       288
# 26  2024      3      March       411
# 27  2024      4      April       152
# 28  2024      5        May       127
# 29  2024      6       June        49
# 30  2024      7       July       133
# 31  2024      8     August       258
# 32  2024      9  September       287
# 33  2024     10    October        49
# 34  2024     11   November         9
# 35  2024     12   December         8

# %%
asd=[]
for i in range(timeline.shape[0]):
    asd.append(timeline['month_name'][i] +"-"+ str(timeline['year'][i]))

# %%
timeline['monthly'] = asd

# %%
fig,ax = plt.subplots()
ax.plot(timeline['monthly'],timeline['user_msg'])
plt.xticks(rotation=90)
plt.show()

# %%
df['only_date'] = df['date'].dt.date
df
# Out:
#                      date           user_name  \
# 0     2022-09-11 21:35:00  group notification
# 1     2022-05-11 21:48:00  group notification
# 2     2022-09-11 21:35:00  group notification
# 3     2022-09-11 21:35:00  group notification
# 4     2022-09-11 21:36:00  group notification
# ...                   ...                 ...
# 22575 2024-04-10 21:31:00     Punya Modi Iiit
# 22576 2024-04-10 21:37:00     Punya Modi Iiit
# 22577 2024-06-10 13:10:00     +91 98175 44050
# 22578 2024-06-10 13:14:00     +91 98175 44050
# 22579 2024-06-10 18:02:00     Punya Modi Iiit
#
#                                                 user_msg  year month_name  \
# 0      Messages and calls are end-to-end encrypted. N...  2022  September
# 1      Labhanshu Meetha created group "Iiit unofficia...  2022        May
# 2                           Labhanshu Meetha added you\n  2022  September
# 3                 Labhanshu Meetha added Protien Iiitb\n  2022  September
# 4               Labhanshu Meetha added +91 99733 25733\n  2022  September
# ...                                                  ...   ...        ...
# 22575                                  <Media omitted>\n  2024      April
# 22576                                                     2024      April
# 22577                                                     2024       June
# 22578  guys do apply in it. It is totally free of cost\n  2024       June
# 22579                                                     2024       June
#
#        day  hour  minute  month   only_date
# 0       11    21      35      9  2022-09-11
# 1       11    21      48      5  2022-05-11
# 2       11    21      35      9  2022-09-11
# 3       11    21      35      9  2022-09-11
# 4       11    21      36      9  2022-09-11
# ...    ...   ...     ...    ...         ...
# 22575   10    21      31      4  2024-04-10
# 22576   10    21      37      4  2024-04-10
# 22577   10    13      10      6  2024-06-10
# 22578   10    13      14      6  2024-06-10
# 22579   10    18       2      6  2024-06-10
#
# [22580 rows x 10 columns]

# %%
daily_timeline = df.groupby('only_date').count()['user_msg'].reset_index()

# %%
plt.plot(daily_timeline['only_date'],daily_timeline['user_msg'])
plt.xticks(rotation=90)
plt.show()

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
weekly_tl = df['day_name'].value_counts().reset_index()

# %%
monthly_tl = df['month_name'].value_counts().reset_index()

# %%
# !pip3 install emoji
# Out:
# Requirement already satisfied: emoji in ./.venv/lib/python3.12/site-packages (2.14.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import emoji

# %%
emojis_list=[]
for msg in df['user_msg']:
    emojis = emoji.distinct_emoji_list(msg)
    emojis_list.extend([emoji.demojize(is_emoji) for is_emoji in emojis])

emojis=[]
for i in emojis_list:
    ans = emoji.emojize(i)
    emojis.extend(ans)

# %%
from collections import Counter
emoji_df = pd.DataFrame(Counter(emojis).most_common(len(emojis)))

# %%
emoji_df
# Out:
#      0     1
# 0    🥳  1771
# 1    🎉  1236
# 2    🎂  1060
# 3    😂   758
# 4    ️   407
# ..  ..   ...
# 398  🪁     1
# 399  💬     1
# 400  🥁     1
# 401  🍿     1
# 402  🐎     1
#
# [403 rows x 2 columns]
